# %%
import pandas as pd

# %%
data = pd.read_csv("Downloads/train.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
print(data.shape)
# Out:
# (891, 12)

# %%
print(data[["PassengerId","Name"]])
# Out:
#      PassengerId                                               Name
# 0              1                            Braund, Mr. Owen Harris
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3                             Heikkinen, Miss. Laina
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5                           Allen, Mr. William Henry
# ..           ...                                                ...
# 886          887                              Montvila, Rev. Juozas
# 887          888                       Graham, Miss. Margaret Edith
# 888          889           Johnston, Miss. Catherine Helen "Carrie"
# 889          890                              Behr, Mr. Karl Howell
# 890          891                                Dooley, Mr. Patrick
#
# [891 rows x 2 columns]

# %%
r,c=data.shape
print(r)
print(c)
# Out:
# 891
# 12

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
print(data[5:10])
# Out:
#    PassengerId  Survived  Pclass  \
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch  Ticket     Fare Cabin Embarked
# 5      0  330877   8.4583   NaN        Q
# 6      0   17463  51.8625   E46        S
# 7      1  349909  21.0750   NaN        S
# 8      2  347742  11.1333   NaN        S
# 9      0  237736  30.0708   NaN        C

# %%
print(data.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
print(data.Name)
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
print(data['Ticket'].min())
# Out:
# 110152

# %%
print(data.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
pd.__version__
# Out:
# '1.3.5'

# %%
a = [1, 7, 2]
myvar = pd.Series(a)

# %%
a
# Out:
# [1, 7, 2]

# %%
myvar = pd.Series(a, index = ["x", "y", "z"])

# %%
myvar
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
df = {
   "calories": [500, 6000, 790],
   "duration": [40, 75, 65]
}

# %%
df
# Out:
# {'calories': [500, 6000, 790], 'duration': [40, 75, 65]}

# %%
df1 = pd.DataFrame(df)

# %%
import pandas as pd

# %%
df1
# Out:
#    calories  duration
# 0       500        40
# 1      6000        75
# 2       790        65

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Drop Null values

# %%
data1 = data.dropna()

# %%
data1.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
print(data1.to_string())
# Out:
#      PassengerId  Survived  Pclass                                                                                Name     Sex    Age  SibSp  Parch             Ticket      Fare            Cabin Embarked
# 1              2         1       1                                 Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.00      1      0           PC 17599   71.2833              C85        C
# 3              4         1       1                                        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00      1      0             113803   53.1000             C123        S
# 6              7         0       1                                                             McCarthy, Mr. Timothy J    male  54.00      0      0              17463   51.8625              E46        S
# 10            11         1       3                                                     Sandstrom, Miss. Marguerite Rut  female   4.00      1      1            PP 9549   16.7000               G6        S
# 11            12         1       1                                                            Bonnell, Miss. Elizabeth  female  58.00      0      0             113783   26.5500             C103        S
# 21            22         1       2                                                               Beesley, Mr. Lawrence    male  34.00      0      0             248698   13.0000              D56        S
# 23            24         1       1                                                        Sloper, Mr. William Thompson    male  28.00      0      0             113788   35.5000               A6        S
# 27            28         0       1                                                      Fortune, Mr. Charles Alexander    male  19.00      3      2              19950  263.0000      C23 C25 C27        S
# 52            53         1       1                                            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49
potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.00      0      1              11767   83.1583              C50        C
# 887          888         1       1                                                        Graham, Miss. Margaret Edith  female  19.00      0      0             112053   30.0000              B42        S
# 889          890         1       1                                                               Behr, Mr. Karl Howell    male  26.00      0      0             111369   30.0000             C148        C

# %% [markdown]
# Replace null values with mean

# %%
data["Age"].fillna(data["Age"].mean(), inplace=True )

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data["Age"]
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt

# %%
x=data['PassengerId']
y=data["Age"]
plt.bar(x,y,label="Age",color="green")
plt.xlabel("Passenger ID")
plt.ylabel("Passenger Age")
plt.title("Passenger Information")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,15))
x=data['PassengerId']
y=data["Ticket"]
plt.bar(x,y,label="Age",color="green")
plt.xlabel("Passenger ID")
plt.ylabel("Passenger Age")
plt.title("Passenger Information")
plt.legend()
plt.show()

# %%
import numpy as np
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.grid()
plt.show()

# %%
plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.grid()
plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
plt.scatter(x,y)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(x,y, color="red")
# Out:
# <BarContainer object of 4 artists>

# %%
#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %%
a = np.random.normal(100,10,200)

# %%
a
# Out:
# array([ 92.30486579,  89.39843967,  94.78410117, 102.77911511,
#         90.15592328, 126.78450293, 100.77255501, 109.78171544,
#         79.10735561,  92.31570919,  89.35259045, 108.8118962 ,
#         87.3166603 , 101.21947848,  99.27756339,  99.3190672 ,
#        102.13179669,  96.49042671,  86.85072299,  96.04904069,
#        104.77609187, 109.75641039, 104.51169107, 103.41790773,
#        112.27905885, 106.01773327,  95.63769962, 101.13273663,
#        119.12563582,  99.42440053,  98.15145313,  94.82106294,
#         91.73919348,  94.82734174, 107.01785907, 116.48036409,
#        106.17500295, 106.54599767, 103.15312027, 103.49691772,
#        111.29795474,  81.11268657,  90.81914387, 104.53228405,
#        100.33290065, 116.2603632 , 102.29357166, 111.89653546,
#         98.16198003,  96.05174717,  87.30478667,  78.50884076,
#        115.3961471 ,  94.70809161,  98.65818288, 118.53927149,
#        102.36399204, 109.36348305, 108.94412051,  90.8425733 ,
#         88.72253384, 103.58624521, 104.90816655, 100.24004573,
#        106.11760002, 102.22569411, 101.32458873,  99.99370484,
#         73.12831196, 103.33279466,  96.6863606 , 103.04547418,
#         93.99797446, 115.25883082, 130.39983015, 100.74499812,
#         92.49421432,  89.42625755, 108.25246206,  97.35848799,
#        110.18025501,  77.81478879,  88.6426078 , 106.16346061,
#         97.42648559,  97.90649636,  94.55882123,  96.43559893,
#         95.91021729, 103.50118837,  91.55000061, 106.01305551,
#        118.06547346,  90.85145636,  96.26507692, 104.57566841,
#         98.35267107,  96.71608527,  84.56994878, 110.59096424,
#         92.70937061, 100.25362983, 104.02628147, 106.6806213 ,
#        110.21007252, 107.56299381, 100.87136625,  91.35628362,
#        117.54635497, 102.95780403, 116.10476247, 101.40693755,
#         90.81249286, 100.58951022, 115.3719984 ,  99.92993718,
#        106.21859212,  84.46207721,  97.92376968,  94.51099789,
#         89.07492368,  85.7400914 , 121.84562687, 107.60510501,
#         96.70776053, 105.34985735, 110.11431563, 103.49750879,
#        102.25647279,  95.74108888,  85.06100685, 107.74463796,
#        104.99919571,  92.82266474, 100.91939113, 103.48661803,
#         88.26553512,  92.3595367 , 100.3812162 , 116.49832083,
#        120.23038108, 118.18646569, 112.77108232, 109.70230289,
#        100.15107983,  93.52028129,  83.4076347 ,  77.00040826,
#        104.62977969, 102.83907785,  98.30481386, 106.63703677,
#         90.75314059,  99.56102044, 104.84003105, 111.04052853,
#         89.82225245,  99.066607  , 100.32072535, 100.85389162,
#        116.71221135, 105.3987353 , 107.59844523,  93.84095768,
#        101.00430641,  94.72687498, 116.34770475, 104.87599801,
#        106.48830308, 107.37392567, 107.33140853, 101.14105715,
#        111.98703591, 107.46472141,  93.92842082,  94.73694442,
#         94.42612942, 113.1048946 , 113.02331422, 104.38581161,
#         91.48659834,  95.09211112,  82.60773307, 101.43787943,
#        101.46687234, 103.81805703,  98.64954513, 110.80308224,
#         90.51823986,  99.69207203, 126.3759904 ,  89.89428448,
#        100.30162198, 102.99063597,  97.67363194,  96.47356032,
#         90.8468612 , 106.82998003, 116.18629834, 104.94422536])

# %%
plt.hist(a)
# Out:
# (array([ 4.,  6., 15., 34., 49., 48., 24., 14.,  3.,  3.]),
#  array([ 73.12831196,  78.85546378,  84.5826156 ,  90.30976742,
#          96.03691924, 101.76407106, 107.49122288, 113.2183747 ,
#         118.94552652, 124.67267834, 130.39983015]),
#  <BarContainer object of 10 artists>)

# %%
y = np.array([35, 25, 25, 10])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = y , startangle = 90)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]


plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.legend()
plt.show()

# %%
plt.boxplot(data["Age"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cf21b75250>,
#   <matplotlib.lines.Line2D at 0x1cf21b75520>],
#  'caps': [<matplotlib.lines.Line2D at 0x1cf21b757f0>,
#   <matplotlib.lines.Line2D at 0x1cf21b75ac0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1cf21b66f40>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cf21b75dc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cf21b830d0>],
#  'means': []}

# %%
plt.bar(data["Age"], data["Pclass"])
# Out:
# <BarContainer object of 891 artists>

# %%
plt.pie(data["Survived"])
# Out:
# ([<matplotlib.patches.Wedge at 0x1cf1f94e400>,
#   <matplotlib.patches.Wedge at 0x1cf1f94e7c0>,
#   <matplotlib.patches.Wedge at 0x1cf1f94eca0>,
#   <matplotlib.patches.Wedge at 0x1cf1f9e01c0>,
#   <matplotlib.patches.Wedge at 0x1cf1f9e06a0>,
#   <matplotlib.patches.Wedge at 0x1cf1f9e0b80>,
#   <matplotlib.patches.Wedge at 0x1cf1f9fd0a0>,
#   <matplotlib.patches.Wedge at 0x1cf1f9fd580>,
#   <matplotlib.patches.Wedge at 0x1cf1f9fda60>,
#   <matplotlib.patches.Wedge at 0x1cf1f9fdf70>,
#   <matplotlib.patches.Wedge at 0x1cf1f94e3d0>,
#   <matplotlib.patches.Wedge at 0x1cf1f9fb940>,
#   <matplotlib.patches.Wedge at 0x1cf1f9fbe20>,
#   <matplotlib.patches.Wedge at 0x1cf1f9e5340>,
#   <matplotlib.patches.Wedge at 0x1cf1f9e5820>,
#   <matplotlib.patches.Wedge at 0x1cf1f9e5d00>,
#   <matplotlib.patches.Wedge at 0x1cf1f9f3220>,
#   <matplotlib.patches.Wedge at 0x1cf1f9f3700>,
#   <matplotlib.patches.Wedge at 0x1cf1f9f3be0>,
#   <matplotlib.patches.Wedge at 0x1cf20e13100>,
#   <matplotlib.patches.Wedge at 0x1cf20e135e0>,
#   <matplotlib.patches.Wedge at 0x1cf20e13ac0>,
#   <matplotlib.patches.Wedge at 0x1cf20e13fa0>,
#   <matplotlib.patches.Wedge at 0x1cf20e1c4c0>,
#   <matplotlib.patches.Wedge at 0x1cf20e1c9a0>,
#   <matplotlib.patches.Wedge at 0x1cf20e1ce80>,
#   <matplotlib.patches.Wedge at 0x1cf20e17550>,
#   <matplotlib.patches.Wedge at 0x1cf20e17a00>,
#   <matplotlib.patches.Wedge at 0x1cf20e175e0>,
#   <matplotlib.patches.Wedge at 0x1cf20e2c280>,
#   <matplotlib.patches.Wedge at 0x1cf20e2c760>,
#   <matplotlib.patches.Wedge at 0x1cf20e2cc40>,
#   <matplotlib.patches.Wedge at 0x1cf205d7160>,
#   <matplotlib.patches.Wedge at 0x1cf205d7640>,
#   <matplotlib.patches.Wedge at 0x1cf205d7b20>,
#   <matplotlib.patches.Wedge at 0x1cf205c5040>,
#   <matplotlib.patches.Wedge at 0x1cf205c5520>,
#   <matplotlib.patches.Wedge at 0x1cf205c5a00>,
#   <matplotlib.patches.Wedge at 0x1cf205c5ee0>,
#   <matplotlib.patches.Wedge at 0x1cf205da400>,
#   <matplotlib.patches.Wedge at 0x1cf205da8e0>,
#   <matplotlib.patches.Wedge at 0x1cf205dadc0>,
#   <matplotlib.patches.Wedge at 0x1cf205ee280>,
#   <matplotlib.patches.Wedge at 0x1cf205eeaf0>,
#   <matplotlib.patches.Wedge at 0x1cf205ee2e0>,
#   <matplotlib.patches.Wedge at 0x1cf1f15f1c0>,
#   <matplotlib.patches.Wedge at 0x1cf1f15f6a0>,
#   <matplotlib.patches.Wedge at 0x1cf1f15fb80>,
#   <matplotlib.patches.Wedge at 0x1cf1f17b0a0>,
#   <matplotlib.patches.Wedge at 0x1cf1f17b580>,
#   <matplotlib.patches.Wedge at 0x1cf1f17ba60>,
#   <matplotlib.patches.Wedge at 0x1cf1f17bf40>,
#   <matplotlib.patches.Wedge at 0x1cf1f1635b0>,
#   <matplotlib.patches.Wedge at 0x1cf1f163ca0>,
#   <matplotlib.patches.Wedge at 0x1cf1f163880>,
#   <matplotlib.patches.Wedge at 0x1cf1f16e340>,
#   <matplotlib.patches.Wedge at 0x1cf1f16e820>,
#   <matplotlib.patches.Wedge at 0x1cf1f16ed00>,
#   <matplotlib.patches.Wedge at 0x1cf1f168220>,
#   <matplotlib.patches.Wedge at 0x1cf1f168700>,
#   <matplotlib.patches.Wedge at 0x1cf1f168be0>,
#   <matplotlib.patches.Wedge at 0x1cf1f3d3100>,
#   <matplotlib.patches.Wedge at 0x1cf1f3d35e0>,
#   <matplotlib.patches.Wedge at 0x1cf1f3d3ac0>,
#   <matplotlib.patches.Wedge at 0x1cf1f3d3fa0>,
#   <matplotlib.patches.Wedge at 0x1cf1f3f94c0>,
#   <matplotlib.patches.Wedge at 0x1cf1f3f99a0>,
#   <matplotlib.patches.Wedge at 0x1cf1f3f9e80>,
#   <matplotlib.patches.Wedge at 0x1cf1f3fe3a0>,
#   <matplotlib.patches.Wedge at 0x1cf1f3fe880>,
#   <matplotlib.patches.Wedge at 0x1cf1f3fed60>,
#   <matplotlib.patches.Wedge at 0x1cf1f3cc280>,
#   <matplotlib.patches.Wedge at 0x1cf1f3cc760>,
#   <matplotlib.patches.Wedge at 0x1cf1f3ccc40>,
#   <matplotlib.patches.Wedge at 0x1cf1f294160>,
#   <matplotlib.patches.Wedge at 0x1cf1f294640>,
#   <matplotlib.patches.Wedge at 0x1cf1f294b20>,
#   <matplotlib.patches.Wedge at 0x1cf1f2a8040>,
#   <matplotlib.patches.Wedge at 0x1cf1f2a8520>,
#   <matplotlib.patches.Wedge at 0x1cf1f2a8a00>,
#   <matplotlib.patches.Wedge at 0x1cf1f2a8ee0>,
#   <matplotlib.patches.Wedge at 0x1cf1f2a3400>,
#   <matplotlib.patches.Wedge at 0x1cf1f2a38e0>,
#   <matplotlib.patches.Wedge at 0x1cf1f2a3dc0>,
#   <matplotlib.patches.Wedge at 0x1cf1f2826d0>,
#   <matplotlib.patches.Wedge at 0x1cf1f282dc0>,
#   <matplotlib.patches.Wedge at 0x1cf1f282910>,
#   <matplotlib.patches.Wedge at 0x1cf1f1f61c0>,
#   <matplotlib.patches.Wedge at 0x1cf1f1f66a0>,
#   <matplotlib.patches.Wedge at 0x1cf1f1f6b80>,
#   <matplotlib.patches.Wedge at 0x1cf1f1e90a0>,
#   <matplotlib.patches.Wedge at 0x1cf1f1e9580>,
#   <matplotlib.patches.Wedge at 0x1cf1f1e9a60>,
#   <matplotlib.patches.Wedge at 0x1cf1f1e9f40>,
#   <matplotlib.patches.Wedge at 0x1cf1f1ed460>,
#   <matplotlib.patches.Wedge at 0x1cf1f1ed940>,
#   <matplotlib.patches.Wedge at 0x1cf1f1ede20>,
#   <matplotlib.patches.Wedge at 0x1cf1f1cb340>,
#   <matplotlib.patches.Wedge at 0x1cf1f1cb820>,
#   <matplotlib.patches.Wedge at 0x1cf1f1cbd00>,
#   <matplotlib.patches.Wedge at 0x1cf20072220>,
#   <matplotlib.patches.Wedge at 0x1cf20072700>,
#   <matplotlib.patches.Wedge at 0x1cf20072be0>,
#   <matplotlib.patches.Wedge at 0x1cf2007b100>,
#   <matplotlib.patches.Wedge at 0x1cf2007b5e0>,
#   <matplotlib.patches.Wedge at 0x1cf2007bac0>,
#   <matplotlib.patches.Wedge at 0x1cf2007bfa0>,
#   <matplotlib.patches.Wedge at 0x1cf2005c4c0>,
#   <matplotlib.patches.Wedge at 0x1cf2005c9a0>,
#   <matplotlib.patches.Wedge at 0x1cf2005ce80>,
#   <matplotlib.patches.Wedge at 0x1cf2004b3a0>,
#   <matplotlib.patches.Wedge at 0x1cf2004b880>,
#   <matplotlib.patches.Wedge at 0x1cf2004bd60>,
#   <matplotlib.patches.Wedge at 0x1cf205aa280>,
#   <matplotlib.patches.Wedge at 0x1cf205aa760>,
#   <matplotlib.patches.Wedge at 0x1cf205aac40>,
#   <matplotlib.patches.Wedge at 0x1cf20585160>,
#   <matplotlib.patches.Wedge at 0x1cf20585640>,
#   <matplotlib.patches.Wedge at 0x1cf20585b20>,
#   <matplotlib.patches.Wedge at 0x1cf205a1040>,
#   <matplotlib.patches.Wedge at 0x1cf205a1520>,
#   <matplotlib.patches.Wedge at 0x1cf205a1a00>,
#   <matplotlib.patches.Wedge at 0x1cf205a1ee0>,
#   <matplotlib.patches.Wedge at 0x1cf205b2400>,
#   <matplotlib.patches.Wedge at 0x1cf205b28e0>,
#   <matplotlib.patches.Wedge at 0x1cf205b2dc0>,
#   <matplotlib.patches.Wedge at 0x1cf1f90e2e0>,
#   <matplotlib.patches.Wedge at 0x1cf1f90e7c0>,
#   <matplotlib.patches.Wedge at 0x1cf1f90eca0>,
#   <matplotlib.patches.Wedge at 0x1cf1f90f1c0>,
#   <matplotlib.patches.Wedge at 0x1cf1f90f6a0>,
#   <matplotlib.patches.Wedge at 0x1cf1f90fb80>,
#   <matplotlib.patches.Wedge at 0x1cf1f90b0a0>,
#   <matplotlib.patches.Wedge at 0x1cf1f90b580>,
#   <matplotlib.patches.Wedge at 0x1cf1f90ba60>,
#   <matplotlib.patches.Wedge at 0x1cf1f90bf40>,
#   <matplotlib.patches.Wedge at 0x1cf1f91c460>,
#   <matplotlib.patches.Wedge at 0x1cf1f91c940>,
#   <matplotlib.patches.Wedge at 0x1cf1f91ce20>,
#   <matplotlib.patches.Wedge at 0x1cf204ca340>,
#   <matplotlib.patches.Wedge at 0x1cf204ca820>,
#   <matplotlib.patches.Wedge at 0x1cf204cad00>,
#   <matplotlib.patches.Wedge at 0x1cf204c2220>,
#   <matplotlib.patches.Wedge at 0x1cf204c2700>,
#   <matplotlib.patches.Wedge at 0x1cf204c2be0>,
#   <matplotlib.patches.Wedge at 0x1cf204d5100>,
#   <matplotlib.patches.Wedge at 0x1cf204d55e0>,
#   <matplotlib.patches.Wedge at 0x1cf204d5ac0>,
#   <matplotlib.patches.Wedge at 0x1cf204d5fa0>,
#   <matplotlib.patches.Wedge at 0x1cf204fa4c0>,
#   <matplotlib.patches.Wedge at 0x1cf204fa9a0>,
#   <matplotlib.patches.Wedge at 0x1cf204fae80>,
#   <matplotlib.patches.Wedge at 0x1cf1f6d73a0>,
#   <matplotlib.patches.Wedge at 0x1cf1f6d7880>,
#   <matplotlib.patches.Wedge at 0x1cf1f6d7d60>,
#   <matplotlib.patches.Wedge at 0x1cf1f6c0280>,
#   <matplotlib.patches.Wedge at 0x1cf1f6c0760>,
#   <matplotlib.patches.Wedge at 0x1cf1f6c0c40>,
#   <matplotlib.patches.Wedge at 0x1cf1f6ca160>,
#   <matplotlib.patches.Wedge at 0x1cf1f6ca640>,
#   <matplotlib.patches.Wedge at 0x1cf1f6cab20>,
#   <matplotlib.patches.Wedge at 0x1cf1f6c8370>,
#   <matplotlib.patches.Wedge at 0x1cf1f6c8a30>,
#   <matplotlib.patches.Wedge at 0x1cf1f6c8dc0>,
#   <matplotlib.patches.Wedge at 0x1cf1f6c89a0>,
#   <matplotlib.patches.Wedge at 0x1cf20fd3400>,
#   <matplotlib.patches.Wedge at 0x1cf20fd38e0>,
#   <matplotlib.patches.Wedge at 0x1cf20fd3dc0>,
#   <matplotlib.patches.Wedge at 0x1cf20fef2e0>,
#   <matplotlib.patches.Wedge at 0x1cf20fef7c0>,
#   <matplotlib.patches.Wedge at 0x1cf20fefca0>,
#   <matplotlib.patches.Wedge at 0x1cf20ff11c0>,
#   <matplotlib.patches.Wedge at 0x1cf20ff16a0>,
#   <matplotlib.patches.Wedge at 0x1cf20ff1b80>,
#   <matplotlib.patches.Wedge at 0x1cf20fcf0a0>,
#   <matplotlib.patches.Wedge at 0x1cf20fcf580>,
#   <matplotlib.patches.Wedge at 0x1cf20fcfa60>,
#   <matplotlib.patches.Wedge at 0x1cf20fcff40>,
#   <matplotlib.patches.Wedge at 0x1cf1f191460>,
#   <matplotlib.patches.Wedge at 0x1cf1f191940>,
#   <matplotlib.patches.Wedge at 0x1cf1f191e20>,
#   <matplotlib.patches.Wedge at 0x1cf1f19e340>,
#   <matplotlib.patches.Wedge at 0x1cf1f19e820>,
#   <matplotlib.patches.Wedge at 0x1cf1f19ed00>,
#   <matplotlib.patches.Wedge at 0x1cf1f1bf220>,
#   <matplotlib.patches.Wedge at 0x1cf1f1bf700>,
#   <matplotlib.patches.Wedge at 0x1cf1f1bfbe0>,
#   <matplotlib.patches.Wedge at 0x1cf1f1ac100>,
#   <matplotlib.patches.Wedge at 0x1cf1f1ac5e0>,
#   <matplotlib.patches.Wedge at 0x1cf1f1acac0>,
#   <matplotlib.patches.Wedge at 0x1cf1f1acfa0>,
#   <matplotlib.patches.Wedge at 0x1cf1fbc34c0>,
#   <matplotlib.patches.Wedge at 0x1cf1fbc39a0>,
#   <matplotlib.patches.Wedge at 0x1cf1fbc3e80>,
#   <matplotlib.patches.Wedge at 0x1cf1fbe23a0>,
#   <matplotlib.patches.Wedge at 0x1cf1fbe2880>,
#   <matplotlib.patches.Wedge at 0x1cf1fbe2d60>,
#   <matplotlib.patches.Wedge at 0x1cf1fbd1280>,
#   <matplotlib.patches.Wedge at 0x1cf1fbd1760>,
#   <matplotlib.patches.Wedge at 0x1cf1fbd1c40>,
#   <matplotlib.patches.Wedge at 0x1cf1fbca160>,
#   <matplotlib.patches.Wedge at 0x1cf1fbca640>,
#   <matplotlib.patches.Wedge at 0x1cf1fbcab20>,
#   <matplotlib.patches.Wedge at 0x1cf1fbe0040>,
#   <matplotlib.patches.Wedge at 0x1cf1fbe0520>,
#   <matplotlib.patches.Wedge at 0x1cf1fbe0a00>,
#   <matplotlib.patches.Wedge at 0x1cf1fbe0ee0>,
#   <matplotlib.patches.Wedge at 0x1cf20006400>,
#   <matplotlib.patches.Wedge at 0x1cf200068e0>,
#   <matplotlib.patches.Wedge at 0x1cf20006dc0>,
#   <matplotlib.patches.Wedge at 0x1cf2002c2e0>,
#   <matplotlib.patches.Wedge at 0x1cf2002c7c0>,
#   <matplotlib.patches.Wedge at 0x1cf2002cca0>,
#   <matplotlib.patches.Wedge at 0x1cf2000f1c0>,
#   <matplotlib.patches.Wedge at 0x1cf2000f6a0>,
#   <matplotlib.patches.Wedge at 0x1cf2000fb80>,
#   <matplotlib.patches.Wedge at 0x1cf2000c0a0>,
#   <matplotlib.patches.Wedge at 0x1cf2000c580>,
#   <matplotlib.patches.Wedge at 0x1cf2000ca60>,
#   <matplotlib.patches.Wedge at 0x1cf2000cf40>,
#   <matplotlib.patches.Wedge at 0x1cf1f36f460>,
#   <matplotlib.patches.Wedge at 0x1cf1f36f940>,
#   <matplotlib.patches.Wedge at 0x1cf1f36fe20>,
#   <matplotlib.patches.Wedge at 0x1cf1f341340>,
#   <matplotlib.patches.Wedge at 0x1cf1f341820>,
#   <matplotlib.patches.Wedge at 0x1cf1f341d00>,
#   <matplotlib.patches.Wedge at 0x1cf1f350220>,
#   <matplotlib.patches.Wedge at 0x1cf1f350700>,
#   <matplotlib.patches.Wedge at 0x1cf1f350be0>,
#   <matplotlib.patches.Wedge at 0x1cf1f36c100>,
#   <matplotlib.patches.Wedge at 0x1cf1f36c5e0>,
#   <matplotlib.patches.Wedge at 0x1cf1f36cac0>,
#   <matplotlib.patches.Wedge at 0x1cf1f36cfa0>,
#   <matplotlib.patches.Wedge at 0x1cf1f2f24c0>,
#   <matplotlib.patches.Wedge at 0x1cf1f2f29a0>,
#   <matplotlib.patches.Wedge at 0x1cf1f2f2e80>,
#   <matplotlib.patches.Wedge at 0x1cf1f2c63a0>,
#   <matplotlib.patches.Wedge at 0x1cf1f2c6880>,
#   <matplotlib.patches.Wedge at 0x1cf1f2c6d60>,
#   <matplotlib.patches.Wedge at 0x1cf1f2c2280>,
#   <matplotlib.patches.Wedge at 0x1cf1f2c2760>,
#   <matplotlib.patches.Wedge at 0x1cf1f2c2c40>,
#   <matplotlib.patches.Wedge at 0x1cf1f2df6d0>,
#   <matplotlib.patches.Wedge at 0x1cf1f2dfa30>,
#   <matplotlib.patches.Wedge at 0x1cf1f2df9d0>,
#   <matplotlib.patches.Wedge at 0x1cf1f2ff040>,
#   <matplotlib.patches.Wedge at 0x1cf1f2ff520>,
#   <matplotlib.patches.Wedge at 0x1cf1f2ffa00>,
#   <matplotlib.patches.Wedge at 0x1cf1f2ffee0>,
#   <matplotlib.patches.Wedge at 0x1cf1f39b400>,
#   <matplotlib.patches.Wedge at 0x1cf1f39b8e0>,
#   <matplotlib.patches.Wedge at 0x1cf1f39bdc0>,
#   <matplotlib.patches.Wedge at 0x1cf1f3982e0>,
#   <matplotlib.patches.Wedge at 0x1cf1f3987c0>,
#   <matplotlib.patches.Wedge at 0x1cf1f398ca0>,
#   <matplotlib.patches.Wedge at 0x1cf1f3be1c0>,
#   <matplotlib.patches.Wedge at 0x1cf1f3be6a0>,
#   <matplotlib.patches.Wedge at 0x1cf1f3beb80>,
#   <matplotlib.patches.Wedge at 0x1cf1f384460>,
#   <matplotlib.patches.Wedge at 0x1cf1f384610>,
#   <matplotlib.patches.Wedge at 0x1cf1f3847c0>,
#   <matplotlib.patches.Wedge at 0x1cf1f384820>,
#   <matplotlib.patches.Wedge at 0x1cf20554430>,
#   <matplotlib.patches.Wedge at 0x1cf20554910>,
#   <matplotlib.patches.Wedge at 0x1cf20554df0>,
#   <matplotlib.patches.Wedge at 0x1cf20542310>,
#   <matplotlib.patches.Wedge at 0x1cf205427f0>,
#   <matplotlib.patches.Wedge at 0x1cf20542cd0>,
#   <matplotlib.patches.Wedge at 0x1cf205551f0>,
#   <matplotlib.patches.Wedge at 0x1cf205556d0>,
#   <matplotlib.patches.Wedge at 0x1cf20555bb0>,
#   <matplotlib.patches.Wedge at 0x1cf205630d0>,
#   <matplotlib.patches.Wedge at 0x1cf205635b0>,
#   <matplotlib.patches.Wedge at 0x1cf20563a90>,
#   <matplotlib.patches.Wedge at 0x1cf20563f70>,
#   <matplotlib.patches.Wedge at 0x1cf20556490>,
#   <matplotlib.patches.Wedge at 0x1cf20556970>,
#   <matplotlib.patches.Wedge at 0x1cf20556e50>,
#   <matplotlib.patches.Wedge at 0x1cf1f7fc370>,
#   <matplotlib.patches.Wedge at 0x1cf1f7fc850>,
#   <matplotlib.patches.Wedge at 0x1cf1f7fcd30>,
#   <matplotlib.patches.Wedge at 0x1cf1f7fe250>,
#   <matplotlib.patches.Wedge at 0x1cf1f7fe730>,
#   <matplotlib.patches.Wedge at 0x1cf1f7fec10>,
#   <matplotlib.patches.Wedge at 0x1cf1f7ed130>,
#   <matplotlib.patches.Wedge at 0x1cf1f7ed610>,
#   <matplotlib.patches.Wedge at 0x1cf1f7edaf0>,
#   <matplotlib.patches.Wedge at 0x1cf1f7edfd0>,
#   <matplotlib.patches.Wedge at 0x1cf1f7f34f0>,
#   <matplotlib.patches.Wedge at 0x1cf1f7f39d0>,
#   <matplotlib.patches.Wedge at 0x1cf1f7f3eb0>,
#   <matplotlib.patches.Wedge at 0x1cf1f7da3d0>,
#   <matplotlib.patches.Wedge at 0x1cf1f7da8b0>,
#   <matplotlib.patches.Wedge at 0x1cf1f7dad90>,
#   <matplotlib.patches.Wedge at 0x1cf1f69d2b0>,
#   <matplotlib.patches.Wedge at 0x1cf1f69d790>,
#   <matplotlib.patches.Wedge at 0x1cf1f69dc70>,
#   <matplotlib.patches.Wedge at 0x1cf1f685190>,
#   <matplotlib.patches.Wedge at 0x1cf1f685670>,
#   <matplotlib.patches.Wedge at 0x1cf1f685b50>,
#   <matplotlib.patches.Wedge at 0x1cf1f68a070>,
#   <matplotlib.patches.Wedge at 0x1cf1f68a550>,
#   <matplotlib.patches.Wedge at 0x1cf1f68aa30>,
#   <matplotlib.patches.Wedge at 0x1cf1f68af10>,
#   <matplotlib.patches.Wedge at 0x1cf1f69a430>,
#   <matplotlib.patches.Wedge at 0x1cf1f69a910>,
#   <matplotlib.patches.Wedge at 0x1cf1f69adf0>,
#   <matplotlib.patches.Wedge at 0x1cf1f319310>,
#   <matplotlib.patches.Wedge at 0x1cf1f3197f0>,
#   <matplotlib.patches.Wedge at 0x1cf1f319cd0>,
#   <matplotlib.patches.Wedge at 0x1cf1f3001f0>,
#   <matplotlib.patches.Wedge at 0x1cf1f3006d0>,
#   <matplotlib.patches.Wedge at 0x1cf1f300bb0>,
#   <matplotlib.patches.Wedge at 0x1cf1f3210d0>,
#   <matplotlib.patches.Wedge at 0x1cf1f3215b0>,
#   <matplotlib.patches.Wedge at 0x1cf1f321a90>,
#   <matplotlib.patches.Wedge at 0x1cf1f321f70>,
#   <matplotlib.patches.Wedge at 0x1cf1f32d490>,
#   <matplotlib.patches.Wedge at 0x1cf1f32d970>,
#   <matplotlib.patches.Wedge at 0x1cf1f32de50>,
#   <matplotlib.patches.Wedge at 0x1cf1f3355e0>,
#   <matplotlib.patches.Wedge at 0x1cf1f335520>,
#   <matplotlib.patches.Wedge at 0x1cf1f335df0>,
#   <matplotlib.patches.Wedge at 0x1cf1f276250>,
#   <matplotlib.patches.Wedge at 0x1cf1f276730>,
#   <matplotlib.patches.Wedge at 0x1cf1f276c10>,
#   <matplotlib.patches.Wedge at 0x1cf1f27e130>,
#   <matplotlib.patches.Wedge at 0x1cf1f27e610>,
#   <matplotlib.patches.Wedge at 0x1cf1f27eaf0>,
#   <matplotlib.patches.Wedge at 0x1cf1f27efd0>,
#   <matplotlib.patches.Wedge at 0x1cf1f25c4f0>,
#   <matplotlib.patches.Wedge at 0x1cf1f25c9d0>,
#   <matplotlib.patches.Wedge at 0x1cf1f25ceb0>,
#   <matplotlib.patches.Wedge at 0x1cf1f2403d0>,
#   <matplotlib.patches.Wedge at 0x1cf1f2408b0>,
#   <matplotlib.patches.Wedge at 0x1cf1f240d90>,
#   <matplotlib.patches.Wedge at 0x1cf1f80c2b0>,
#   <matplotlib.patches.Wedge at 0x1cf1f80c790>,
#   <matplotlib.patches.Wedge at 0x1cf1f80cc70>,
#   <matplotlib.patches.Wedge at 0x1cf1f837190>,
#   <matplotlib.patches.Wedge at 0x1cf1f837670>,
#   <matplotlib.patches.Wedge at 0x1cf1f837b50>,
#   <matplotlib.patches.Wedge at 0x1cf1f8083d0>,
#   <matplotlib.patches.Wedge at 0x1cf1f808490>,
#   <matplotlib.patches.Wedge at 0x1cf1f8084f0>,
#   <matplotlib.patches.Wedge at 0x1cf1f808a90>,
#   <matplotlib.patches.Wedge at 0x1cf1f810430>,
#   <matplotlib.patches.Wedge at 0x1cf1f810910>,
#   <matplotlib.patches.Wedge at 0x1cf1f810df0>,
#   <matplotlib.patches.Wedge at 0x1cf1f83d130>,
#   <matplotlib.patches.Wedge at 0x1cf1f83d6d0>,
#   <matplotlib.patches.Wedge at 0x1cf1f83d640>,
#   <matplotlib.patches.Wedge at 0x1cf205011f0>,
#   <matplotlib.patches.Wedge at 0x1cf205016d0>,
#   <matplotlib.patches.Wedge at 0x1cf20501bb0>,
#   <matplotlib.patches.Wedge at 0x1cf205140d0>,
#   <matplotlib.patches.Wedge at 0x1cf205145b0>,
#   <matplotlib.patches.Wedge at 0x1cf20514a90>,
#   <matplotlib.patches.Wedge at 0x1cf20514f70>,
#   <matplotlib.patches.Wedge at 0x1cf2052b490>,
#   <matplotlib.patches.Wedge at 0x1cf2052b970>,
#   <matplotlib.patches.Wedge at 0x1cf2052be50>,
#   <matplotlib.patches.Wedge at 0x1cf20537370>,
#   <matplotlib.patches.Wedge at 0x1cf20537850>,
#   <matplotlib.patches.Wedge at 0x1cf20537d30>,
#   <matplotlib.patches.Wedge at 0x1cf1f674250>,
#   <matplotlib.patches.Wedge at 0x1cf1f674730>,
#   <matplotlib.patches.Wedge at 0x1cf1f674c10>,
#   <matplotlib.patches.Wedge at 0x1cf1f649130>,
#   <matplotlib.patches.Wedge at 0x1cf1f649610>,
#   <matplotlib.patches.Wedge at 0x1cf1f649af0>,
#   <matplotlib.patches.Wedge at 0x1cf1f649fd0>,
#   <matplotlib.patches.Wedge at 0x1cf1f64c6a0>,
#   <matplotlib.patches.Wedge at 0x1cf1f64ce80>,
#   <matplotlib.patches.Wedge at 0x1cf1f64cbb0>,
#   <matplotlib.patches.Wedge at 0x1cf1f6633d0>,
#   <matplotlib.patches.Wedge at 0x1cf1f6638b0>,
#   <matplotlib.patches.Wedge at 0x1cf1f663d90>,
#   <matplotlib.patches.Wedge at 0x1cf1f67c2b0>,
#   <matplotlib.patches.Wedge at 0x1cf1f67c790>,
#   <matplotlib.patches.Wedge at 0x1cf1f67cc70>,
#   <matplotlib.patches.Wedge at 0x1cf1f613190>,
#   <matplotlib.patches.Wedge at 0x1cf1f613670>,
#   <matplotlib.patches.Wedge at 0x1cf1f613b50>,
#   <matplotlib.patches.Wedge at 0x1cf1f62e070>,
#   <matplotlib.patches.Wedge at 0x1cf1f62e550>,
#   <matplotlib.patches.Wedge at 0x1cf1f62ea30>,
#   <matplotlib.patches.Wedge at 0x1cf1f62ef10>,
#   <matplotlib.patches.Wedge at 0x1cf1f624430>,
#   <matplotlib.patches.Wedge at 0x1cf1f624910>,
#   <matplotlib.patches.Wedge at 0x1cf1f624df0>,
#   <matplotlib.patches.Wedge at 0x1cf1f623310>,
#   <matplotlib.patches.Wedge at 0x1cf1f6237f0>,
#   <matplotlib.patches.Wedge at 0x1cf1f623cd0>,
#   <matplotlib.patches.Wedge at 0x1cf1fb701f0>,
#   <matplotlib.patches.Wedge at 0x1cf1fb706d0>,
#   <matplotlib.patches.Wedge at 0x1cf1fb70bb0>,
#   <matplotlib.patches.Wedge at 0x1cf1fb780d0>,
#   <matplotlib.patches.Wedge at 0x1cf1fb785b0>,
#   <matplotlib.patches.Wedge at 0x1cf1fb78a90>,
#   <matplotlib.patches.Wedge at 0x1cf1fb78f70>,
#   <matplotlib.patches.Wedge at 0x1cf1fb62490>,
#   <matplotlib.patches.Wedge at 0x1cf1fb62970>,
#   <matplotlib.patches.Wedge at 0x1cf1fb62e50>,
#   <matplotlib.patches.Wedge at 0x1cf1fb4b370>,
#   <matplotlib.patches.Wedge at 0x1cf1fb4b850>,
#   <matplotlib.patches.Wedge at 0x1cf1fb4bd30>,
#   <matplotlib.patches.Wedge at 0x1cf1fb66250>,
#   <matplotlib.patches.Wedge at 0x1cf1fb66730>,
#   <matplotlib.patches.Wedge at 0x1cf1fb66c10>,
#   <matplotlib.patches.Wedge at 0x1cf1f203130>,
#   <matplotlib.patches.Wedge at 0x1cf1f203610>,
#   <matplotlib.patches.Wedge at 0x1cf1f203af0>,
#   <matplotlib.patches.Wedge at 0x1cf1f203fd0>,
#   <matplotlib.patches.Wedge at 0x1cf1f21f4f0>,
#   <matplotlib.patches.Wedge at 0x1cf1f21f9d0>,
#   <matplotlib.patches.Wedge at 0x1cf1f21feb0>,
#   <matplotlib.patches.Wedge at 0x1cf1f22c3d0>,
#   <matplotlib.patches.Wedge at 0x1cf1f22c8b0>,
#   <matplotlib.patches.Wedge at 0x1cf1f22cd90>,
#   <matplotlib.patches.Wedge at 0x1cf1f22f2b0>,
#   <matplotlib.patches.Wedge at 0x1cf1f22f790>,
#   <matplotlib.patches.Wedge at 0x1cf1f22fc70>,
#   <matplotlib.patches.Wedge at 0x1cf1f23b190>,
#   <matplotlib.patches.Wedge at 0x1cf1f23b670>,
#   <matplotlib.patches.Wedge at 0x1cf1f23bb50>,
#   <matplotlib.patches.Wedge at 0x1cf1fb8b070>,
#   <matplotlib.patches.Wedge at 0x1cf1fb8b550>,
#   <matplotlib.patches.Wedge at 0x1cf1fb8ba30>,
#   <matplotlib.patches.Wedge at 0x1cf1fb8bf10>,
#   <matplotlib.patches.Wedge at 0x1cf1fbaf430>,
#   <matplotlib.patches.Wedge at 0x1cf1fbaf910>,
#   <matplotlib.patches.Wedge at 0x1cf1fbafdf0>,
#   <matplotlib.patches.Wedge at 0x1cf1fb97310>,
#   <matplotlib.patches.Wedge at 0x1cf1fb977f0>,
#   <matplotlib.patches.Wedge at 0x1cf1fb97cd0>,
#   <matplotlib.patches.Wedge at 0x1cf1fba61f0>,
#   <matplotlib.patches.Wedge at 0x1cf1fba66d0>,
#   <matplotlib.patches.Wedge at 0x1cf1fba6bb0>,
#   <matplotlib.patches.Wedge at 0x1cf200b40d0>,
#   <matplotlib.patches.Wedge at 0x1cf200b45b0>,
#   <matplotlib.patches.Wedge at 0x1cf200b4a90>,
#   <matplotlib.patches.Wedge at 0x1cf200b4f70>,
#   <matplotlib.patches.Wedge at 0x1cf200bc490>,
#   <matplotlib.patches.Wedge at 0x1cf200bc970>,
#   <matplotlib.patches.Wedge at 0x1cf200bce50>,
#   <matplotlib.patches.Wedge at 0x1cf200a8370>,
#   <matplotlib.patches.Wedge at 0x1cf200a8850>,
#   <matplotlib.patches.Wedge at 0x1cf200a8d30>,
#   <matplotlib.patches.Wedge at 0x1cf2008c250>,
#   <matplotlib.patches.Wedge at 0x1cf2008c730>,
#   <matplotlib.patches.Wedge at 0x1cf2008cc10>,
#   <matplotlib.patches.Wedge at 0x1cf2008f130>,
#   <matplotlib.patches.Wedge at 0x1cf2008f610>,
#   <matplotlib.patches.Wedge at 0x1cf2008faf0>,
#   <matplotlib.patches.Wedge at 0x1cf2008ffd0>,
#   <matplotlib.patches.Wedge at 0x1cf200c44f0>,
#   <matplotlib.patches.Wedge at 0x1cf200c49d0>,
#   <matplotlib.patches.Wedge at 0x1cf200c4eb0>,
#   <matplotlib.patches.Wedge at 0x1cf200d23d0>,
#   <matplotlib.patches.Wedge at 0x1cf200d28b0>,
#   <matplotlib.patches.Wedge at 0x1cf200d2d90>,
#   <matplotlib.patches.Wedge at 0x1cf200e02b0>,
#   <matplotlib.patches.Wedge at 0x1cf200e0790>,
#   <matplotlib.patches.Wedge at 0x1cf200e0c70>,
#   <matplotlib.patches.Wedge at 0x1cf200ed190>,
#   <matplotlib.patches.Wedge at 0x1cf200ed670>,
#   <matplotlib.patches.Wedge at 0x1cf200edb50>,
#   <matplotlib.patches.Wedge at 0x1cf200f9070>,
#   <matplotlib.patches.Wedge at 0x1cf200f9550>,
#   <matplotlib.patches.Wedge at 0x1cf200f9a30>,
#   <matplotlib.patches.Wedge at 0x1cf200f9f10>,
#   <matplotlib.patches.Wedge at 0x1cf20107430>,
#   <matplotlib.patches.Wedge at 0x1cf20107910>,
#   <matplotlib.patches.Wedge at 0x1cf20107df0>,
#   <matplotlib.patches.Wedge at 0x1cf20115310>,
#   <matplotlib.patches.Wedge at 0x1cf201157f0>,
#   <matplotlib.patches.Wedge at 0x1cf20115cd0>,
#   <matplotlib.patches.Wedge at 0x1cf201211f0>,
#   <matplotlib.patches.Wedge at 0x1cf201216d0>,
#   <matplotlib.patches.Wedge at 0x1cf20121bb0>,
#   <matplotlib.patches.Wedge at 0x1cf2012f0d0>,
#   <matplotlib.patches.Wedge at 0x1cf2012f5b0>,
#   <matplotlib.patches.Wedge at 0x1cf2012fa90>,
#   <matplotlib.patches.Wedge at 0x1cf2012ff70>,
#   <matplotlib.patches.Wedge at 0x1cf2013c490>,
#   <matplotlib.patches.Wedge at 0x1cf2013c970>,
#   <matplotlib.patches.Wedge at 0x1cf2013ce50>,
#   <matplotlib.patches.Wedge at 0x1cf2014a370>,
#   <matplotlib.patches.Wedge at 0x1cf2014a850>,
#   <matplotlib.patches.Wedge at 0x1cf2014ad30>,
#   <matplotlib.patches.Wedge at 0x1cf20157250>,
#   <matplotlib.patches.Wedge at 0x1cf20157730>,
#   <matplotlib.patches.Wedge at 0x1cf20157c10>,
#   <matplotlib.patches.Wedge at 0x1cf20163130>,
#   <matplotlib.patches.Wedge at 0x1cf20163610>,
#   <matplotlib.patches.Wedge at 0x1cf20163af0>,
#   <matplotlib.patches.Wedge at 0x1cf20163fd0>,
#   <matplotlib.patches.Wedge at 0x1cf201714f0>,
#   <matplotlib.patches.Wedge at 0x1cf201719d0>,
#   <matplotlib.patches.Wedge at 0x1cf20171eb0>,
#   <matplotlib.patches.Wedge at 0x1cf201803d0>,
#   <matplotlib.patches.Wedge at 0x1cf201808b0>,
#   <matplotlib.patches.Wedge at 0x1cf20180d90>,
#   <matplotlib.patches.Wedge at 0x1cf2018c2b0>,
#   <matplotlib.patches.Wedge at 0x1cf2018c790>,
#   <matplotlib.patches.Wedge at 0x1cf2018cc70>,
#   <matplotlib.patches.Wedge at 0x1cf20199190>,
#   <matplotlib.patches.Wedge at 0x1cf20199670>,
#   <matplotlib.patches.Wedge at 0x1cf20199b50>,
#   <matplotlib.patches.Wedge at 0x1cf201a6070>,
#   <matplotlib.patches.Wedge at 0x1cf201a6550>,
#   <matplotlib.patches.Wedge at 0x1cf201a6a30>,
#   <matplotlib.patches.Wedge at 0x1cf201a6f10>,
#   <matplotlib.patches.Wedge at 0x1cf201b4430>,
#   <matplotlib.patches.Wedge at 0x1cf201b4910>,
#   <matplotlib.patches.Wedge at 0x1cf201b4df0>,
#   <matplotlib.patches.Wedge at 0x1cf201c0310>,
#   <matplotlib.patches.Wedge at 0x1cf201c07f0>,
#   <matplotlib.patches.Wedge at 0x1cf201c0cd0>,
#   <matplotlib.patches.Wedge at 0x1cf201cf1f0>,
#   <matplotlib.patches.Wedge at 0x1cf201cf6d0>,
#   <matplotlib.patches.Wedge at 0x1cf201cfbb0>,
#   <matplotlib.patches.Wedge at 0x1cf201da0d0>,
#   <matplotlib.patches.Wedge at 0x1cf201da5b0>,
#   <matplotlib.patches.Wedge at 0x1cf201daa90>,
#   <matplotlib.patches.Wedge at 0x1cf201daf70>,
#   <matplotlib.patches.Wedge at 0x1cf201e8490>,
#   <matplotlib.patches.Wedge at 0x1cf201e8970>,
#   <matplotlib.patches.Wedge at 0x1cf201e8e50>,
#   <matplotlib.patches.Wedge at 0x1cf201f7370>,
#   <matplotlib.patches.Wedge at 0x1cf201f7850>,
#   <matplotlib.patches.Wedge at 0x1cf201f7d30>,
#   <matplotlib.patches.Wedge at 0x1cf20204250>,
#   <matplotlib.patches.Wedge at 0x1cf20204730>,
#   <matplotlib.patches.Wedge at 0x1cf20204c10>,
#   <matplotlib.patches.Wedge at 0x1cf2020e130>,
#   <matplotlib.patches.Wedge at 0x1cf2020e610>,
#   <matplotlib.patches.Wedge at 0x1cf2020eaf0>,
#   <matplotlib.patches.Wedge at 0x1cf2020efd0>,
#   <matplotlib.patches.Wedge at 0x1cf2021f4f0>,
#   <matplotlib.patches.Wedge at 0x1cf2021f9d0>,
#   <matplotlib.patches.Wedge at 0x1cf2021feb0>,
#   <matplotlib.patches.Wedge at 0x1cf2022c3d0>,
#   <matplotlib.patches.Wedge at 0x1cf2022c8b0>,
#   <matplotlib.patches.Wedge at 0x1cf2022cd90>,
#   <matplotlib.patches.Wedge at 0x1cf202392b0>,
#   <matplotlib.patches.Wedge at 0x1cf20239790>,
#   <matplotlib.patches.Wedge at 0x1cf20239c70>,
#   <matplotlib.patches.Wedge at 0x1cf20246190>,
#   <matplotlib.patches.Wedge at 0x1cf20246670>,
#   <matplotlib.patches.Wedge at 0x1cf20246b50>,
#   <matplotlib.patches.Wedge at 0x1cf20253070>,
#   <matplotlib.patches.Wedge at 0x1cf20253550>,
#   <matplotlib.patches.Wedge at 0x1cf20253a30>,
#   <matplotlib.patches.Wedge at 0x1cf20253f10>,
#   <matplotlib.patches.Wedge at 0x1cf20261430>,
#   <matplotlib.patches.Wedge at 0x1cf20261910>,
#   <matplotlib.patches.Wedge at 0x1cf20261df0>,
#   <matplotlib.patches.Wedge at 0x1cf2026d310>,
#   <matplotlib.patches.Wedge at 0x1cf2026d7f0>,
#   <matplotlib.patches.Wedge at 0x1cf2026dcd0>,
#   <matplotlib.patches.Wedge at 0x1cf2027b1f0>,
#   <matplotlib.patches.Wedge at 0x1cf2027b6d0>,
#   <matplotlib.patches.Wedge at 0x1cf2027bbb0>,
#   <matplotlib.patches.Wedge at 0x1cf202880d0>,
#   <matplotlib.patches.Wedge at 0x1cf202885b0>,
#   <matplotlib.patches.Wedge at 0x1cf20288a90>,
#   <matplotlib.patches.Wedge at 0x1cf20288f70>,
#   <matplotlib.patches.Wedge at 0x1cf20295490>,
#   <matplotlib.patches.Wedge at 0x1cf20295970>,
#   <matplotlib.patches.Wedge at 0x1cf20295e50>,
#   <matplotlib.patches.Wedge at 0x1cf202a2370>,
#   <matplotlib.patches.Wedge at 0x1cf202a2850>,
#   <matplotlib.patches.Wedge at 0x1cf202a2d30>,
#   <matplotlib.patches.Wedge at 0x1cf202b0250>,
#   <matplotlib.patches.Wedge at 0x1cf202b0730>,
#   <matplotlib.patches.Wedge at 0x1cf202b0c10>,
#   <matplotlib.patches.Wedge at 0x1cf202bd130>,
#   <matplotlib.patches.Wedge at 0x1cf202bd610>,
#   <matplotlib.patches.Wedge at 0x1cf202bdaf0>,
#   <matplotlib.patches.Wedge at 0x1cf202bdfd0>,
#   <matplotlib.patches.Wedge at 0x1cf202ca4f0>,
#   <matplotlib.patches.Wedge at 0x1cf202ca9d0>,
#   <matplotlib.patches.Wedge at 0x1cf202caeb0>,
#   <matplotlib.patches.Wedge at 0x1cf202d83d0>,
#   <matplotlib.patches.Wedge at 0x1cf202d88b0>,
#   <matplotlib.patches.Wedge at 0x1cf202d8d90>,
#   <matplotlib.patches.Wedge at 0x1cf202e52b0>,
#   <matplotlib.patches.Wedge at 0x1cf202e5790>,
#   <matplotlib.patches.Wedge at 0x1cf202e5c70>,
#   <matplotlib.patches.Wedge at 0x1cf202f4190>,
#   <matplotlib.patches.Wedge at 0x1cf202f4670>,
#   <matplotlib.patches.Wedge at 0x1cf202f4b50>,
#   <matplotlib.patches.Wedge at 0x1cf202fe070>,
#   <matplotlib.patches.Wedge at 0x1cf202fe550>,
#   <matplotlib.patches.Wedge at 0x1cf202fea30>,
#   <matplotlib.patches.Wedge at 0x1cf202fef10>,
#   <matplotlib.patches.Wedge at 0x1cf2030d430>,
#   <matplotlib.patches.Wedge at 0x1cf2030d910>,
#   <matplotlib.patches.Wedge at 0x1cf2030ddf0>,
#   <matplotlib.patches.Wedge at 0x1cf2031a310>,
#   <matplotlib.patches.Wedge at 0x1cf2031a7f0>,
#   <matplotlib.patches.Wedge at 0x1cf2031acd0>,
#   <matplotlib.patches.Wedge at 0x1cf203281f0>,
#   <matplotlib.patches.Wedge at 0x1cf203286d0>,
#   <matplotlib.patches.Wedge at 0x1cf20328bb0>,
#   <matplotlib.patches.Wedge at 0x1cf203350d0>,
#   <matplotlib.patches.Wedge at 0x1cf203355b0>,
#   <matplotlib.patches.Wedge at 0x1cf20335a90>,
#   <matplotlib.patches.Wedge at 0x1cf20335f70>,
#   <matplotlib.patches.Wedge at 0x1cf20342490>,
#   <matplotlib.patches.Wedge at 0x1cf20342970>,
#   <matplotlib.patches.Wedge at 0x1cf20342e50>,
#   <matplotlib.patches.Wedge at 0x1cf2034f370>,
#   <matplotlib.patches.Wedge at 0x1cf2034f850>,
#   <matplotlib.patches.Wedge at 0x1cf2034fd30>,
#   <matplotlib.patches.Wedge at 0x1cf2035c250>,
#   <matplotlib.patches.Wedge at 0x1cf2035c730>,
#   <matplotlib.patches.Wedge at 0x1cf2035cc10>,
#   <matplotlib.patches.Wedge at 0x1cf2036a130>,
#   <matplotlib.patches.Wedge at 0x1cf2036a610>,
#   <matplotlib.patches.Wedge at 0x1cf2036aaf0>,
#   <matplotlib.patches.Wedge at 0x1cf2036afd0>,
#   <matplotlib.patches.Wedge at 0x1cf203774f0>,
#   <matplotlib.patches.Wedge at 0x1cf203779d0>,
#   <matplotlib.patches.Wedge at 0x1cf20377eb0>,
#   <matplotlib.patches.Wedge at 0x1cf203843d0>,
#   <matplotlib.patches.Wedge at 0x1cf203848b0>,
#   <matplotlib.patches.Wedge at 0x1cf20384d90>,
#   <matplotlib.patches.Wedge at 0x1cf203922b0>,
#   <matplotlib.patches.Wedge at 0x1cf20392790>,
#   <matplotlib.patches.Wedge at 0x1cf20392c70>,
#   <matplotlib.patches.Wedge at 0x1cf203a0190>,
#   <matplotlib.patches.Wedge at 0x1cf203a0670>,
#   <matplotlib.patches.Wedge at 0x1cf203a0b50>,
#   <matplotlib.patches.Wedge at 0x1cf203ac070>,
#   <matplotlib.patches.Wedge at 0x1cf203ac550>,
#   <matplotlib.patches.Wedge at 0x1cf203aca30>,
#   <matplotlib.patches.Wedge at 0x1cf203acf10>,
#   <matplotlib.patches.Wedge at 0x1cf203b9430>,
#   <matplotlib.patches.Wedge at 0x1cf203b9910>,
#   <matplotlib.patches.Wedge at 0x1cf203b9df0>,
#   <matplotlib.patches.Wedge at 0x1cf203c6310>,
#   <matplotlib.patches.Wedge at 0x1cf203c67f0>,
#   <matplotlib.patches.Wedge at 0x1cf203c6cd0>,
#   <matplotlib.patches.Wedge at 0x1cf203d41f0>,
#   <matplotlib.patches.Wedge at 0x1cf203d46d0>,
#   <matplotlib.patches.Wedge at 0x1cf203d4bb0>,
#   <matplotlib.patches.Wedge at 0x1cf203e10d0>,
#   <matplotlib.patches.Wedge at 0x1cf203e15b0>,
#   <matplotlib.patches.Wedge at 0x1cf203e1a90>,
#   <matplotlib.patches.Wedge at 0x1cf203e1f70>,
#   <matplotlib.patches.Wedge at 0x1cf203ee490>,
#   <matplotlib.patches.Wedge at 0x1cf203ee970>,
#   <matplotlib.patches.Wedge at 0x1cf203eee50>,
#   <matplotlib.patches.Wedge at 0x1cf203fd370>,
#   <matplotlib.patches.Wedge at 0x1cf203fd850>,
#   <matplotlib.patches.Wedge at 0x1cf203fdd30>,
#   <matplotlib.patches.Wedge at 0x1cf20409250>,
#   <matplotlib.patches.Wedge at 0x1cf20409730>,
#   <matplotlib.patches.Wedge at 0x1cf20409c10>,
#   <matplotlib.patches.Wedge at 0x1cf20415130>,
#   <matplotlib.patches.Wedge at 0x1cf20415610>,
#   <matplotlib.patches.Wedge at 0x1cf20415af0>,
#   <matplotlib.patches.Wedge at 0x1cf20415fd0>,
#   <matplotlib.patches.Wedge at 0x1cf204254f0>,
#   <matplotlib.patches.Wedge at 0x1cf204259d0>,
#   <matplotlib.patches.Wedge at 0x1cf20425eb0>,
#   <matplotlib.patches.Wedge at 0x1cf204313d0>,
#   <matplotlib.patches.Wedge at 0x1cf204318b0>,
#   <matplotlib.patches.Wedge at 0x1cf20431d90>,
#   <matplotlib.patches.Wedge at 0x1cf2043f2b0>,
#   <matplotlib.patches.Wedge at 0x1cf2043f790>,
#   <matplotlib.patches.Wedge at 0x1cf2043fc70>,
#   <matplotlib.patches.Wedge at 0x1cf2044c190>,
#   <matplotlib.patches.Wedge at 0x1cf2044c670>,
#   <matplotlib.patches.Wedge at 0x1cf2044cb50>,
#   <matplotlib.patches.Wedge at 0x1cf20458070>,
#   <matplotlib.patches.Wedge at 0x1cf20458550>,
#   <matplotlib.patches.Wedge at 0x1cf20458a30>,
#   <matplotlib.patches.Wedge at 0x1cf20458f10>,
#   <matplotlib.patches.Wedge at 0x1cf20467430>,
#   <matplotlib.patches.Wedge at 0x1cf20467910>,
#   <matplotlib.patches.Wedge at 0x1cf20467df0>,
#   <matplotlib.patches.Wedge at 0x1cf20473310>,
#   <matplotlib.patches.Wedge at 0x1cf204737f0>,
#   <matplotlib.patches.Wedge at 0x1cf20473cd0>,
#   <matplotlib.patches.Wedge at 0x1cf220c01f0>,
#   <matplotlib.patches.Wedge at 0x1cf220c06d0>,
#   <matplotlib.patches.Wedge at 0x1cf220c0bb0>,
#   <matplotlib.patches.Wedge at 0x1cf220ce0d0>,
#   <matplotlib.patches.Wedge at 0x1cf220ce5b0>,
#   <matplotlib.patches.Wedge at 0x1cf220cea90>,
#   <matplotlib.patches.Wedge at 0x1cf220cef70>,
#   <matplotlib.patches.Wedge at 0x1cf220db490>,
#   <matplotlib.patches.Wedge at 0x1cf220db970>,
#   <matplotlib.patches.Wedge at 0x1cf220dbe50>,
#   <matplotlib.patches.Wedge at 0x1cf220e7370>,
#   <matplotlib.patches.Wedge at 0x1cf220e7850>,
#   <matplotlib.patches.Wedge at 0x1cf220e7d30>,
#   <matplotlib.patches.Wedge at 0x1cf220f6250>,
#   <matplotlib.patches.Wedge at 0x1cf220f6730>,
#   <matplotlib.patches.Wedge at 0x1cf220f6c10>,
#   <matplotlib.patches.Wedge at 0x1cf22102130>,
#   <matplotlib.patches.Wedge at 0x1cf22102610>,
#   <matplotlib.patches.Wedge at 0x1cf22102af0>,
#   <matplotlib.patches.Wedge at 0x1cf22102fd0>,
#   <matplotlib.patches.Wedge at 0x1cf221104f0>,
#   <matplotlib.patches.Wedge at 0x1cf221109d0>,
#   <matplotlib.patches.Wedge at 0x1cf22110eb0>,
#   <matplotlib.patches.Wedge at 0x1cf2211d3d0>,
#   <matplotlib.patches.Wedge at 0x1cf2211d8b0>,
#   <matplotlib.patches.Wedge at 0x1cf2211dd90>,
#   <matplotlib.patches.Wedge at 0x1cf2212b2b0>,
#   <matplotlib.patches.Wedge at 0x1cf2212b790>,
#   <matplotlib.patches.Wedge at 0x1cf2212bc70>,
#   <matplotlib.patches.Wedge at 0x1cf22139190>,
#   <matplotlib.patches.Wedge at 0x1cf22139670>,
#   <matplotlib.patches.Wedge at 0x1cf22139b50>,
#   <matplotlib.patches.Wedge at 0x1cf22144070>,
#   <matplotlib.patches.Wedge at 0x1cf22144550>,
#   <matplotlib.patches.Wedge at 0x1cf22144a30>,
#   <matplotlib.patches.Wedge at 0x1cf22144f10>,
#   <matplotlib.patches.Wedge at 0x1cf22154430>,
#   <matplotlib.patches.Wedge at 0x1cf22154910>,
#   <matplotlib.patches.Wedge at 0x1cf22154df0>,
#   <matplotlib.patches.Wedge at 0x1cf22160310>,
#   <matplotlib.patches.Wedge at 0x1cf221607f0>,
#   <matplotlib.patches.Wedge at 0x1cf22160cd0>,
#   <matplotlib.patches.Wedge at 0x1cf2216c1f0>,
#   <matplotlib.patches.Wedge at 0x1cf2216c6d0>,
#   <matplotlib.patches.Wedge at 0x1cf2216cbb0>,
#   <matplotlib.patches.Wedge at 0x1cf2217a0d0>,
#   <matplotlib.patches.Wedge at 0x1cf2217a5b0>,
#   <matplotlib.patches.Wedge at 0x1cf2217aa90>,
#   <matplotlib.patches.Wedge at 0x1cf2217af70>,
#   <matplotlib.patches.Wedge at 0x1cf22189490>,
#   <matplotlib.patches.Wedge at 0x1cf22189970>,
#   <matplotlib.patches.Wedge at 0x1cf22189e50>,
#   <matplotlib.patches.Wedge at 0x1cf22194370>,
#   <matplotlib.patches.Wedge at 0x1cf22194850>,
#   <matplotlib.patches.Wedge at 0x1cf22194d30>,
#   <matplotlib.patches.Wedge at 0x1cf221a1250>,
#   <matplotlib.patches.Wedge at 0x1cf221a1730>,
#   <matplotlib.patches.Wedge at 0x1cf221a1c10>,
#   <matplotlib.patches.Wedge at 0x1cf221ae130>,
#   <matplotlib.patches.Wedge at 0x1cf221ae610>,
#   <matplotlib.patches.Wedge at 0x1cf221aeaf0>,
#   <matplotlib.patches.Wedge at 0x1cf221aefd0>,
#   <matplotlib.patches.Wedge at 0x1cf221be4f0>,
#   <matplotlib.patches.Wedge at 0x1cf221be9d0>,
#   <matplotlib.patches.Wedge at 0x1cf221beeb0>,
#   <matplotlib.patches.Wedge at 0x1cf221cb3d0>,
#   <matplotlib.patches.Wedge at 0x1cf221cb8b0>,
#   <matplotlib.patches.Wedge at 0x1cf221cbd90>,
#   <matplotlib.patches.Wedge at 0x1cf221d72b0>,
#   <matplotlib.patches.Wedge at 0x1cf221d7790>,
#   <matplotlib.patches.Wedge at 0x1cf221d7c70>,
#   <matplotlib.patches.Wedge at 0x1cf221e4190>,
#   <matplotlib.patches.Wedge at 0x1cf221e4670>,
#   <matplotlib.patches.Wedge at 0x1cf221e4b50>,
#   <matplotlib.patches.Wedge at 0x1cf221f2070>,
#   <matplotlib.patches.Wedge at 0x1cf221f2550>,
#   <matplotlib.patches.Wedge at 0x1cf221f2a30>,
#   <matplotlib.patches.Wedge at 0x1cf221f2f10>,
#   <matplotlib.patches.Wedge at 0x1cf22200430>,
#   <matplotlib.patches.Wedge at 0x1cf22200910>,
#   <matplotlib.patches.Wedge at 0x1cf22200df0>,
#   <matplotlib.patches.Wedge at 0x1cf2220b310>,
#   <matplotlib.patches.Wedge at 0x1cf2220b7f0>,
#   <matplotlib.patches.Wedge at 0x1cf2220bcd0>,
#   <matplotlib.patches.Wedge at 0x1cf2221a1f0>,
#   <matplotlib.patches.Wedge at 0x1cf2221a6d0>,
#   <matplotlib.patches.Wedge at 0x1cf2221abb0>,
#   <matplotlib.patches.Wedge at 0x1cf222270d0>,
#   <matplotlib.patches.Wedge at 0x1cf222275b0>,
#   <matplotlib.patches.Wedge at 0x1cf22227a90>,
#   <matplotlib.patches.Wedge at 0x1cf22227f70>,
#   <matplotlib.patches.Wedge at 0x1cf22234490>,
#   <matplotlib.patches.Wedge at 0x1cf22234970>,
#   <matplotlib.patches.Wedge at 0x1cf22234e50>,
#   <matplotlib.patches.Wedge at 0x1cf22242370>,
#   <matplotlib.patches.Wedge at 0x1cf22242850>,
#   <matplotlib.patches.Wedge at 0x1cf22242d30>,
#   <matplotlib.patches.Wedge at 0x1cf2224f250>,
#   <matplotlib.patches.Wedge at 0x1cf2224f730>,
#   <matplotlib.patches.Wedge at 0x1cf2224fc10>,
#   <matplotlib.patches.Wedge at 0x1cf2225b130>,
#   <matplotlib.patches.Wedge at 0x1cf2225b610>,
#   <matplotlib.patches.Wedge at 0x1cf2225baf0>,
#   <matplotlib.patches.Wedge at 0x1cf2225bfd0>,
#   <matplotlib.patches.Wedge at 0x1cf2226a4f0>,
#   <matplotlib.patches.Wedge at 0x1cf2226a9d0>,
#   <matplotlib.patches.Wedge at 0x1cf2226aeb0>,
#   <matplotlib.patches.Wedge at 0x1cf222773d0>,
#   <matplotlib.patches.Wedge at 0x1cf222778b0>,
#   <matplotlib.patches.Wedge at 0x1cf22277d90>,
#   <matplotlib.patches.Wedge at 0x1cf222842b0>,
#   <matplotlib.patches.Wedge at 0x1cf22284790>,
#   <matplotlib.patches.Wedge at 0x1cf22284c70>,
#   <matplotlib.patches.Wedge at 0x1cf22291190>,
#   <matplotlib.patches.Wedge at 0x1cf22291670>,
#   <matplotlib.patches.Wedge at 0x1cf22291b50>,
#   <matplotlib.patches.Wedge at 0x1cf2229e070>,
#   <matplotlib.patches.Wedge at 0x1cf2229e550>,
#   <matplotlib.patches.Wedge at 0x1cf2229ea30>,
#   <matplotlib.patches.Wedge at 0x1cf2229ef10>,
#   <matplotlib.patches.Wedge at 0x1cf222ad430>,
#   <matplotlib.patches.Wedge at 0x1cf222ad910>,
#   <matplotlib.patches.Wedge at 0x1cf222addf0>,
#   <matplotlib.patches.Wedge at 0x1cf222b8310>,
#   <matplotlib.patches.Wedge at 0x1cf222b87f0>,
#   <matplotlib.patches.Wedge at 0x1cf222b8cd0>,
#   <matplotlib.patches.Wedge at 0x1cf222c61f0>,
#   <matplotlib.patches.Wedge at 0x1cf222c66d0>,
#   <matplotlib.patches.Wedge at 0x1cf222c6bb0>,
#   <matplotlib.patches.Wedge at 0x1cf222d40d0>,
#   <matplotlib.patches.Wedge at 0x1cf222d45b0>,
#   <matplotlib.patches.Wedge at 0x1cf222d4a90>,
#   <matplotlib.patches.Wedge at 0x1cf222d4f70>,
#   <matplotlib.patches.Wedge at 0x1cf222e1490>,
#   <matplotlib.patches.Wedge at 0x1cf222e1970>,
#   <matplotlib.patches.Wedge at 0x1cf222e1e50>,
#   <matplotlib.patches.Wedge at 0x1cf222ed370>,
#   <matplotlib.patches.Wedge at 0x1cf222ed850>,
#   <matplotlib.patches.Wedge at 0x1cf222edd30>,
#   <matplotlib.patches.Wedge at 0x1cf222fd250>,
#   <matplotlib.patches.Wedge at 0x1cf222fd730>,
#   <matplotlib.patches.Wedge at 0x1cf222fdc10>,
#   <matplotlib.patches.Wedge at 0x1cf22308130>,
#   <matplotlib.patches.Wedge at 0x1cf22308610>,
#   <matplotlib.patches.Wedge at 0x1cf22308af0>,
#   <matplotlib.patches.Wedge at 0x1cf22308fd0>,
#   <matplotlib.patches.Wedge at 0x1cf223154f0>,
#   <matplotlib.patches.Wedge at 0x1cf223159d0>,
#   <matplotlib.patches.Wedge at 0x1cf22315eb0>,
#   <matplotlib.patches.Wedge at 0x1cf223233d0>,
#   <matplotlib.patches.Wedge at 0x1cf223238b0>,
#   <matplotlib.patches.Wedge at 0x1cf22323d90>,
#   <matplotlib.patches.Wedge at 0x1cf223322b0>,
#   <matplotlib.patches.Wedge at 0x1cf22332790>,
#   <matplotlib.patches.Wedge at 0x1cf22332c70>,
#   <matplotlib.patches.Wedge at 0x1cf2233e190>,
#   <matplotlib.patches.Wedge at 0x1cf2233e670>,
#   <matplotlib.patches.Wedge at 0x1cf2233eb50>,
#   <matplotlib.patches.Wedge at 0x1cf2234a070>,
#   <matplotlib.patches.Wedge at 0x1cf2234a550>,
#   <matplotlib.patches.Wedge at 0x1cf2234aa30>,
#   <matplotlib.patches.Wedge at 0x1cf2234af10>,
#   <matplotlib.patches.Wedge at 0x1cf22359430>,
#   <matplotlib.patches.Wedge at 0x1cf22359910>,
#   <matplotlib.patches.Wedge at 0x1cf22359df0>,
#   <matplotlib.patches.Wedge at 0x1cf22366310>,
#   <matplotlib.patches.Wedge at 0x1cf223667f0>,
#   <matplotlib.patches.Wedge at 0x1cf22366cd0>,
#   <matplotlib.patches.Wedge at 0x1cf223731f0>,
#   <matplotlib.patches.Wedge at 0x1cf223736d0>,
#   <matplotlib.patches.Wedge at 0x1cf22373bb0>,
#   <matplotlib.patches.Wedge at 0x1cf223800d0>,
#   <matplotlib.patches.Wedge at 0x1cf223805b0>,
#   <matplotlib.patches.Wedge at 0x1cf22380a90>,
#   <matplotlib.patches.Wedge at 0x1cf22380f70>,
#   <matplotlib.patches.Wedge at 0x1cf2238d490>,
#   <matplotlib.patches.Wedge at 0x1cf2238d970>,
#   <matplotlib.patches.Wedge at 0x1cf2238de50>,
#   <matplotlib.patches.Wedge at 0x1cf2239b370>,
#   <matplotlib.patches.Wedge at 0x1cf2239b850>,
#   <matplotlib.patches.Wedge at 0x1cf2239bd30>,
#   <matplotlib.patches.Wedge at 0x1cf223a8250>,
#   <matplotlib.patches.Wedge at 0x1cf223a8730>,
#   <matplotlib.patches.Wedge at 0x1cf223a8c10>,
#   <matplotlib.patches.Wedge at 0x1cf223b5130>,
#   <matplotlib.patches.Wedge at 0x1cf223b5610>,
#   <matplotlib.patches.Wedge at 0x1cf223b5af0>,
#   <matplotlib.patches.Wedge at 0x1cf223b5fd0>,
#   <matplotlib.patches.Wedge at 0x1cf223c24f0>,
#   <matplotlib.patches.Wedge at 0x1cf223c29d0>,
#   <matplotlib.patches.Wedge at 0x1cf223c2eb0>,
#   <matplotlib.patches.Wedge at 0x1cf223d13d0>,
#   <matplotlib.patches.Wedge at 0x1cf223d18b0>,
#   <matplotlib.patches.Wedge at 0x1cf223d1d90>,
#   <matplotlib.patches.Wedge at 0x1cf223dd2b0>,
#   <matplotlib.patches.Wedge at 0x1cf223dd790>,
#   <matplotlib.patches.Wedge at 0x1cf223ddc70>,
#   <matplotlib.patches.Wedge at 0x1cf223eb190>,
#   <matplotlib.patches.Wedge at 0x1cf223eb670>,
#   <matplotlib.patches.Wedge at 0x1cf223ebb50>,
#   <matplotlib.patches.Wedge at 0x1cf223f7070>,
#   <matplotlib.patches.Wedge at 0x1cf223f7550>,
#   <matplotlib.patches.Wedge at 0x1cf223f7a30>],
#  [Text(1.1, 0.0, ''),
#   Text(1.0999535904694522, 0.010104395744480493, ''),
#   Text(1.0995823377212235, 0.030309776830746465, ''),
#   Text(1.0988399575287826, 0.05050492785999538, ''),
#   Text(1.0983296680517645, 0.06059653684247412, ''),
#   Text(1.0983296680517645, 0.06059653684247412, ''),
#   Text(1.0983296680517645, 0.06059653684247412, ''),
#   Text(1.0983296680517645, 0.06059653684247412, ''),
#   Text(1.097726700457871, 0.07068303263072069, ''),
#   Text(1.0962429422513844, 0.09083728069481341, ''),
#   Text(1.0943891837025526, 0.11096086965620235, ''),
#   Text(1.0921660504859152, 0.13104700746677672, ''),
#   Text(1.09091619799659, 0.14107391306923098, ''),
#   Text(1.09091619799659, 0.14107391306923098, ''),
#   Text(1.09091619799659, 0.14107391306923098, ''),
#   Text(1.0895742929461443, 0.15108891471881597, ''),
#   Text(1.088140448565821, 0.16109116734003165, ''),
#   Text(1.0866147858447917, 0.17107982693315338, ''),
#   Text(1.0849974335199486, 0.1810540506454493, ''),
#   Text(1.083288528065041, 0.19101299684230105, ''),
#   Text(1.08148821367916, 0.2009558251782219, ''),
#   Text(1.0795966422745695, 0.2108816966677656, ''),
#   Text(1.0755403745466272, 0.23067922039078603, ''),
#   Text(1.0711210939394682, 0.2503988860157273, ''),
#   Text(1.068775785152732, 0.26022744104179596, ''),
#   Text(1.0663402920342686, 0.27003403782536556, ''),
#   Text(1.0638148200933366, 0.27981784887633987, ''),
#   Text(1.0638148200933366, 0.27981784887633987, ''),
#   Text(1.0611995824316944, 0.2895780486273045, ''),
#   Text(1.0584947997256189, 0.2993138135031895, ''),
#   Text(1.0584947997256189, 0.2993138135031895, ''),
#   Text(1.0557007002072838, 0.30902432199076313, ''),
#   Text(1.0498455013258297, 0.32836629447298227, ''),
#   Text(1.0467848960300405, 0.33799612637333176, ''),
#   Text(1.0467848960300405, 0.33799612637333176, ''),
#   Text(1.0467848960300405, 0.33799612637333176, ''),
#   Text(1.0436359620149613, 0.3475974378344957, ''),
#   Text(1.0403989649906822, 0.3571694186885514, ''),
#   Text(1.0403989649906822, 0.3571694186885514, ''),
#   Text(1.0370741780981338, 0.3667112612425207, ''),
#   Text(1.0336618818860421, 0.3762221603465248, ''),
#   Text(1.0336618818860421, 0.3762221603465248, ''),
#   Text(1.0336618818860421, 0.3762221603465248, ''),
#   Text(1.0301623642872526, 0.3857013134617226, ''),
#   Text(1.0229028534351714, 0.40456118503161453, ''),
#   Text(1.0191434727464084, 0.41394031207215276, ''),
#   Text(1.0191434727464084, 0.41394031207215276, ''),
#   Text(1.0152980957483155, 0.423284510429858, ''),
#   Text(1.0113670469175138, 0.43259299163225895, ''),
#   Text(1.0113670469175138, 0.43259299163225895, ''),
#   Text(1.0113670469175138, 0.43259299163225895, ''),
#   Text(1.0776139837998038, -0.22078972330957025, ''),
#   Text(1.0776139837998038, -0.22078972330957025, ''),
#   Text(1.079596652146653, -0.21088164612819932, ''),
#   Text(1.0814882230865797, -0.2009557745501048, ''),
#   Text(1.0814882230865797, -0.2009557745501048, ''),
#   Text(1.0832885370070036, -0.1910129461299052, ''),
#   Text(1.086614793853615, -0.17107977606504424, ''),
#   Text(1.0881404561070416, -0.1610911164005011, ''),
#   Text(1.0881404561070416, -0.1610911164005011, ''),
#   Text(1.0895743000191256, -0.15108886371216237, ''),
#   Text(1.0909162046007352, -0.14107386199975833, ''),
#   Text(1.092166056620667, -0.1310469563387943, ''),
#   Text(1.0933237506152023, -0.12100899280924218, ''),
#   Text(1.0933237506152023, -0.12100899280924218, ''),
#   Text(1.0943891888970045, -0.11096081842414761, ''),
#   Text(1.096242946503783, -0.09083722937597803, ''),
#   Text(1.097031109406904, -0.08076351276075878, ''),
#   Text(1.097031109406904, -0.08076351276075878, ''),
#   Text(1.097031109406904, -0.08076351276075878, ''),
#   Text(1.0977267037667815, -0.07068298124242564, ''),
#   Text(1.0988399598930878, -0.0505048764195851, ''),
#   Text(1.099257527721891, -0.040409005763027084, ''),
#   Text(1.099257527721891, -0.040409005763027084, ''),
#   Text(1.099257527721891, -0.040409005763027084, ''),
#   Text(1.099257527721891, -0.040409005763027084, ''),
#   Text(1.099257527721891, -0.040409005763027084, ''),
#   Text(1.099257527721891, -0.040409005763027084, ''),
#   Text(1.0995823391401252, -0.03030972535558293, ''),
#   Text(1.0998143667398899, -0.020207887384275522, ''),
#   Text(1.0999535909424718, -0.010104344251936466, ''),
#   Text(1.0999999999999988, 5.149471657675648e-08, '')])

# %%
import seaborn as sns

# %%
import pandas as pd
import numpy as np
import random

# Set seed for reproducibility
np.random.seed(42)
random.seed(42)

# Generate random data for 100 rows
cities = ['CityA', 'CityB', 'CityC', 'CityD']
days = ['Sunday','Monday', 'Tuesday','Wednesday','Thursday','Friday','Saturday']
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

data = {
    'City': [random.choice(cities) for _ in range(1000)],
    'Day': [random.choice(days) for _ in range(1000)],
    'Month': [random.choice(months) for _ in range(1000)],
    'Temperature': np.random.uniform(0, 30, 1000)  # Random temperatures between 0 and 30
}

# Create a DataFrame
df = pd.DataFrame(data)

# Save DataFrame to CSV file
df.to_csv('temperature.csv', index=False)

# %%
data = pd.read_csv('temperature_data.csv')

# %%
d1 = pd.read_csv('temperature.csv')

# %%
d1
# Out:
#       City        Day Month  Temperature
# 0    CityA     Sunday   Oct    11.236204
# 1    CityA     Friday   Feb    28.521429
# 2    CityC     Monday   Mar    21.959818
# 3    CityB     Friday   Jun    17.959755
# 4    CityB     Friday   Nov     4.680559
# ..     ...        ...   ...          ...
# 995  CityD  Wednesday   Sep     2.747462
# 996  CityC   Thursday   Jul    27.519407
# 997  CityB  Wednesday   Feb     4.104559
# 998  CityA   Saturday   Jan    28.507121
# 999  CityD  Wednesday   Feb    13.380173
#
# [1000 rows x 4 columns]
