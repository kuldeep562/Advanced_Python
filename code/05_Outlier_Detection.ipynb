# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('Downloads/train.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
plt.boxplot(data['Fare'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2af6e8f2490>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2af6e8f2ac0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2af6e8f22e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2af6e8f2fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2af6e9092e0>],
#  'means': []}

# %%
plt.figure(figsize=(20,20))
plt.boxplot(data["Fare"], vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2af6e9ee880>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2af6e9eee50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2af6e9ee5b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2af70c0d430>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2af70c0d700>],
#  'means': []}

# %%
plt.figure(figsize=(20,20))

plt.barh(data["Fare"],data["Age"])
# Out:
# <BarContainer object of 891 artists>

# %%
import numpy as np
outliers = []
def detect_outliers_zscore(data):
    thres = 3
    mean = np.mean(data)
    std = np.std(data)
    # print(mean, std)
    for i in data:
        z_score = (i-mean)/std
        if (np.abs(z_score) > thres):
            outliers.append(i)
    return outliers# Driver code
sample_outliers = detect_outliers_zscore(data["Fare"])
print("Outliers from Z-scores method: ", sample_outliers)
# Out:
# Outliers from Z-scores method:  [263.0, 263.0, 247.5208, 512.3292, 247.5208, 262.375, 263.0, 211.5, 227.525, 263.0, 221.7792, 227.525, 512.3292, 211.3375, 227.525, 227.525, 211.3375, 512.3292, 262.375, 211.3375]

# %%
sample_outliers
# Out:
# [263.0,
#  263.0,
#  247.5208,
#  512.3292,
#  247.5208,
#  262.375,
#  263.0,
#  211.5,
#  227.525,
#  263.0,
#  221.7792,
#  227.525,
#  512.3292,
#  211.3375,
#  227.525,
#  227.525,
#  211.3375,
#  512.3292,
#  262.375,
#  211.3375]

# %%
for i in sample:
    a = np.delete(sample_outliers,np.where(sample==i))
print(a)
# print(len(sample), len(a))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <module>
# ----> 1 for i in sample:
#       2     a = np.delete(sample_outliers,np.where(sample==i))
#       3 print(a)
#
# NameError: name 'sample' is not defined

# %%
sample=[]
for i in data["Fare"]:
    sample.append(i)

# %%
sample
# Out:
# [7.25,
#  71.2833,
#  7.925,
#  53.1,
#  8.05,
#  8.4583,
#  51.8625,
#  21.075,
#  11.1333,
#  30.0708,
#  16.7,
#  26.55,
#  8.05,
#  31.275,
#  7.8542,
#  16.0,
#  29.125,
#  13.0,
#  18.0,
#  7.225,
#  26.0,
#  13.0,
#  8.0292,
#  35.5,
#  21.075,
#  31.3875,
#  7.225,
#  263.0,
#  7.8792,
#  7.8958,
#  27.7208,
#  146.5208,
#  7.75,
#  10.5,
#  82.1708,
#  52.0,
#  7.2292,
#  8.05,
#  18.0,
#  11.2417,
#  9.475,
#  21.0,
#  7.8958,
#  41.5792,
#  7.8792,
#  8.05,
#  15.5,
#  7.75,
#  21.6792,
#  17.8,
#  39.6875,
#  7.8,
#  76.7292,
#  26.0,
#  61.9792,
#  35.5,
#  10.5,
#  7.2292,
#  27.75,
#  46.9,
#  7.2292,
#  80.0,
#  83.475,
#  27.9,
#  27.7208,
#  15.2458,
#  10.5,
#  8.1583,
#  7.925,
#  8.6625,
#  10.5,
#  46.9,
#  73.5,
#  14.4542,
#  56.4958,
#  7.65,
#  7.8958,
#  8.05,
#  29.0,
#  12.475,
#  9.0,
#  9.5,
#  7.7875,
#  47.1,
#  10.5,
#  15.85,
#  34.375,
#  8.05,
#  263.0,
#  8.05,
#  8.05,
#  7.8542,
#  61.175,
#  20.575,
#  7.25,
#  8.05,
#  34.6542,
#  63.3583,
# ...

# %%
Fare_new = pd.DataFrame(sample)

# %%
Fare_new
# Out:
#            0
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# ..       ...
# 886  13.0000
# 887  30.0000
# 888  23.4500
# 889  30.0000
# 890   7.7500
#
# [891 rows x 1 columns]

# %%
data.insert(2, "Fare_new", a, True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <module>
# ----> 1 data.insert(2, "Fare_new", a, True)
#
# NameError: name 'a' is not defined

# %%
median = np.median(data["Fare"])# Replace with median

# %%
median
# Out:
# 14.4542

# %%
for i in sample_outliers:
    c = np.where(data["Fare"]==i, median, data["Fare"])
print("Sample: ", data["Fare"])
print("New array: ",c)
# Out:
# Sample:  0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64
# New array:  [  7.25    71.2833   7.925   53.1      8.05     8.4583  51.8625  21.075
#   11.1333  30.0708  16.7     26.55     8.05    31.275    7.8542  16.
#   29.125   13.      18.       7.225   26.      13.       8.0292  35.5
#   21.075   31.3875   7.225  263.       7.8792   7.8958  27.7208 146.5208
#    7.75    10.5     82.1708  52.       7.2292   8.05    18.      11.2417
#    9.475   21.       7.8958  41.5792   7.8792   8.05    15.5      7.75
#   21.6792  17.8     39.6875   7.8     76.7292  26.      61.9792  35.5
#   10.5      7.2292  27.75    46.9      7.2292  80.      83.475   27.9
#   27.7208  15.2458  10.5      8.1583   7.925    8.6625  10.5     46.9
#   73.5     14.4542  56.4958   7.65     7.8958   8.05    29.      12.475
# ...

# %%
for i in data["Fare"]:
    for j in sample_outliers:
        dat["Fare"] = np.where(i==j, median, data["Fare"])
#print("Sample: ", data["Fare"])
#print("New array: ",c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [18], in <module>
#       1 for i in data["Fare"]:
#       2     for j in sample_outliers:
# ----> 3         dat["Fare"] = np.where(i==j, median, data["Fare"])
#
# NameError: name 'dat' is not defined

# %%
c
# Out:
# array([  7.25  ,  71.2833,   7.925 ,  53.1   ,   8.05  ,   8.4583,
#         51.8625,  21.075 ,  11.1333,  30.0708,  16.7   ,  26.55  ,
#          8.05  ,  31.275 ,   7.8542,  16.    ,  29.125 ,  13.    ,
#         18.    ,   7.225 ,  26.    ,  13.    ,   8.0292,  35.5   ,
#         21.075 ,  31.3875,   7.225 , 263.    ,   7.8792,   7.8958,
#         27.7208, 146.5208,   7.75  ,  10.5   ,  82.1708,  52.    ,
#          7.2292,   8.05  ,  18.    ,  11.2417,   9.475 ,  21.    ,
#          7.8958,  41.5792,   7.8792,   8.05  ,  15.5   ,   7.75  ,
#         21.6792,  17.8   ,  39.6875,   7.8   ,  76.7292,  26.    ,
#         61.9792,  35.5   ,  10.5   ,   7.2292,  27.75  ,  46.9   ,
#          7.2292,  80.    ,  83.475 ,  27.9   ,  27.7208,  15.2458,
#         10.5   ,   8.1583,   7.925 ,   8.6625,  10.5   ,  46.9   ,
#         73.5   ,  14.4542,  56.4958,   7.65  ,   7.8958,   8.05  ,
#         29.    ,  12.475 ,   9.    ,   9.5   ,   7.7875,  47.1   ,
# ...

# %%
plt.boxplot(c, vert=False)
plt.title("Boxplot of the sample after treating the outliers")
# Out:
# Text(0.5, 1.0, 'Boxplot of the sample after treating the outliers')

# %%
data["Fare"]
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
plt.boxplot(data["Fare"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2af73761490>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2af73761a30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2af737612e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2af73761fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2af737692e0>],
#  'means': []}

# %%
import seaborn as sns
sns.boxplot(data["Fare"])
# Out:
# <AxesSubplot:>

# %%
for i in data["Fare"]:
    q1 = data["Fare"].quantile(0.25)
    q3= data["Fare"].quantile(0.75)
    iqr=q3-q1
    lower = q1-1.5*iqr
    upper = q3+1.5*iqr
    if i > upper or i < lower:
        data["Fare"] = data["Fare"].replace(i, np.mean(data["Fare"]))

# %%
sns.boxplot(data["Fare"])
# Out:
# <AxesSubplot:>

# %%
for i in data["Fare"]:
    q1 = data["Fare"].quantile(0.25)
    q3= data["Fare"].quantile(0.75)
    iqr=q3-q1
    lower = q1-1.5*iqr
    upper = q3+1.5*iqr
    if i > upper or i < lower:
        data["Fare"] = data["Fare"].replace(i, np.median(data["Fare"]))

# %%
sns.boxplot(data["Fare"])
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_X = sc_X.fit_transform(data)
#Convert to table format - StandardScaler 
sc_X = pd.DataFrame(data=sc_X, columns=["Age"])
sc_X
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [28], in <module>
#       1 from sklearn.preprocessing import StandardScaler
#       2 sc_X = StandardScaler()
# ----> 3 sc_X = sc_X.fit_transform(data)
#       4 #Convert to table format - StandardScaler
#       5 sc_X = pd.DataFrame(data=sc_X, columns=["Age"])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py:867, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     863 # non-optimized default implementation; override when a better
#     864 # method is possible for a given clustering algorithm
#     865 if y is None:
#     866     # fit method of arity 1 (unsupervised transformation)
# --> 867     return self.fit(X, **fit_params).transform(X)
#     868 else:
# ...
